# %% [markdown]
# # SPX Members- Momentum Strategy

# %% [markdown]
# This is a trading method that trades members of the SPX index using a momentum methodology from Andreas Clenow.
#
# The only data required is index membership and historical price data.
#
# The method calculates a 'momentum score' for each equity by fitting an exponential regression slope to their returns (fig1).
#
# Those with higher returns are preferred- however he also mutiplies this value by the coefficient of determination AKA the R-squared value.  This penalizes highly volatile stocks in favour of more consistent ones.  In general volatility is considered a negative but this also prevents stocks such as the theoretical one in fig2 from scoring highly simply due to a takeover announcement which resulted in a 50% increase.
#
# *fig1*
# <img src="fig1.png">
#
# *fig2*
# <img src="fig2.png">

# %%
""" Imports and parameter setep """

# %matplotlib inline
import zipline
from zipline.finance.commission import PerDollar
from zipline.api import order_target_percent, symbol, schedule_function, date_rules, time_rules, set_commission

from datetime import datetime, timedelta
import pytz
import pandas as pd
import numpy as np
import matplotlib as plt
import pyfolio as pf
from scipy import stats

path_to_data = 'K:/Share/Personal/Ryan/CFA/TradingBook/ProjectOne/'

#Parameters
start_val = 10000000
momentum_window = 126 # half a year
min_momentum_score = 40 # arbitrary number so that we only buy stocks with strong momentum
portfolio_size = 30
vol_window = 20
commission_pct = 0.0

# %%
""" Helper Functions """

def momentum_score(ts):
    x = np.arange(len(ts))
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, np.log(ts))
    annualized_slope = (np.power(np.exp(slope),252)-1) * 100
    score = annualized_slope * (r_value **2)
    return score

def volatility(ts):
    return ts.pct_change().rolling(vol_window).std().iloc[-1]

# %%
""" Universe setup and trade execution """

def initialize(context):
    #set comission
    set_commission(PerDollar(cost=commission_pct))
    
    #index members file
    context.index_members = pd.read_csv(path_to_data + 'index-member-data.csv', index_col=0, parse_dates=[0])

    schedule_function(
        func=rebalance,
        date_rule=date_rules.month_start(),
        time_rule=time_rules.market_open())

def rebalance(context, data):
    # get current data and index makeup on this date
    today = zipline.api.get_datetime().normalize()
    index_constituents = context.index_members.loc[context.index_members.index == today]
    todays_universe = [symbol(ticker) for ticker in index_constituents.loc[:]['BBGID']]
    
    # zipline function which gives selected history and time for given universe
    hist = data.history(assets=todays_universe, fields="close", bar_count=momentum_window, frequency="1d") 
    
    # create momentum ranking table
    ranking_table = hist.apply(momentum_score)
    ranking_table = ranking_table.sort_values(ascending=False)
    
    """ Sell Logic & Execution """
    kept_positions = list(context.portfolio.positions.keys())
    
    for security in context.portfolio.positions:
        # check if no longer in index or if momentum score has risen above threshold
        if (security not in todays_universe) or (ranking_table[security] < min_momentum_score):
            order_target_percent(security, 0.0)
            kept_positions.remove(security)
    
    """ Buy Logic """
    # check how many stocks required to take us to portfolio size
    replacement_number = portfolio_size - len(kept_positions)
    buy_list = ranking_table.loc[~ranking_table.index.isin(kept_positions)][:replacement_number]
    updated_portfolio = pd.concat((buy_list, ranking_table.loc[ranking_table.index.isin(kept_positions)]))
    
    """ Buy Sizing & Execution """
    vol_table = hist[updated_portfolio.index].apply(volatility)
    inv_vol_table = 1.0 / vol_table
    target_weights = inv_vol_table / np.sum(inv_vol_table)
    
    for security, rank in updated_portfolio.iteritems():
        if (security in kept_positions) or (ranking_table[security] > min_momentum_score):
            order_target_percent(security, target_weights[security])
            
def analyze(context, perf):
    returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
    pf.create_full_tear_sheet(returns, positions, transactions, benchmark_rets=None)

# %%
""" Set Dates """
start = datetime(1998, 1, 1, tzinfo=pytz.UTC)
end = datetime(2018, 12, 31, tzinfo=pytz.UTC)

# %%
""" Run Backtest """
result = zipline.run_algorithm(start=start, end=end,
                               initialize=initialize,
                               analyze=analyze,
                               capital_base=start_val,
                               data_frequency='daily',
                               bundle='random_stock_data')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1998-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>251</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>12.6%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>1092.6%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.6%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-35.8%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.14</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.10</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>6.97</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.4%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>3.9%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>35.85</td>
#       <td>2007-10-29</td>
#       <td>2009-07-07</td>
#       <td>2010-03-23</td>
#       <td>627</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>34.65</td>
#       <td>2001-05-21</td>
#       <td>2003-03-11</td>
#       <td>2003-10-03</td>
#       <td>620</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28.42</td>
#       <td>2000-03-27</td>
#       <td>2000-04-14</td>
#       <td>2000-12-27</td>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>21.25</td>
#       <td>1998-07-20</td>
#       <td>1998-08-31</td>
#       <td>1999-04-01</td>
#       <td>184</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>18.50</td>
#       <td>2006-05-09</td>
#       <td>2006-06-13</td>
#       <td>2007-04-09</td>
#       <td>240</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\rlavery_lst\AppData\Local\Continuum\Anaconda2\envs\zip35\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dotcom</th>
#       <td>0.03%</td>
#       <td>-10.02%</td>
#       <td>10.85%</td>
#     </tr>
#     <tr>
#       <th>Lehman</th>
#       <td>-0.28%</td>
#       <td>-5.03%</td>
#       <td>2.70%</td>
#     </tr>
#     <tr>
#       <th>9/11</th>
#       <td>-0.11%</td>
#       <td>-6.74%</td>
#       <td>4.71%</td>
#     </tr>
#     <tr>
#       <th>US downgrade/European Debt Crisis</th>
#       <td>0.12%</td>
#       <td>-4.41%</td>
#       <td>3.93%</td>
#     </tr>
#     <tr>
#       <th>Fukushima</th>
#       <td>0.20%</td>
#       <td>-1.92%</td>
#       <td>2.22%</td>
#     </tr>
#     <tr>
#       <th>US Housing</th>
#       <td>-0.51%</td>
#       <td>-2.78%</td>
#       <td>2.10%</td>
#     </tr>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>-0.03%</td>
#       <td>-2.13%</td>
#       <td>1.33%</td>
#     </tr>
#     <tr>
#       <th>Aug07</th>
#       <td>0.09%</td>
#       <td>-3.33%</td>
#       <td>3.65%</td>
#     </tr>
#     <tr>
#       <th>Mar08</th>
#       <td>-0.00%</td>
#       <td>-2.84%</td>
#       <td>2.60%</td>
#     </tr>
#     <tr>
#       <th>Sept08</th>
#       <td>-0.33%</td>
#       <td>-3.59%</td>
#       <td>2.70%</td>
#     </tr>
#     <tr>
#       <th>2009Q1</th>
#       <td>-0.01%</td>
#       <td>-0.16%</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <th>2009Q2</th>
#       <td>0.06%</td>
#       <td>-3.19%</td>
#       <td>2.50%</td>
#     </tr>
#     <tr>
#       <th>Flash Crash</th>
#       <td>-0.14%</td>
#       <td>-3.69%</td>
#       <td>6.80%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.11%</td>
#       <td>-3.56%</td>
#       <td>2.61%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.06%</td>
#       <td>-2.69%</td>
#       <td>2.37%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>-0.14%</td>
#       <td>-3.90%</td>
#       <td>3.92%</td>
#     </tr>
#     <tr>
#       <th>Low Volatility Bull Market</th>
#       <td>0.04%</td>
#       <td>-3.67%</td>
#       <td>5.24%</td>
#     </tr>
#     <tr>
#       <th>GFC Crash</th>
#       <td>-0.05%</td>
#       <td>-5.03%</td>
#       <td>4.64%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>0.05%</td>
#       <td>-5.17%</td>
#       <td>6.80%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.06%</td>
#       <td>-4.36%</td>
#       <td>3.92%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>BBG000BFF1J4</th>
#       <td>53.57%</td>
#     </tr>
#     <tr>
#       <th>BBG000BP2H92</th>
#       <td>51.96%</td>
#     </tr>
#     <tr>
#       <th>BBG000BX3B60</th>
#       <td>41.53%</td>
#     </tr>
#     <tr>
#       <th>BBG000BD3J49</th>
#       <td>36.09%</td>
#     </tr>
#     <tr>
#       <th>BBG000CYF8C4</th>
#       <td>35.99%</td>
#     </tr>
#     <tr>
#       <th>BBG000BQ5TK8</th>
#       <td>35.66%</td>
#     </tr>
#     <tr>
#       <th>BBG000CKJ0P3</th>
#       <td>35.40%</td>
#     </tr>
#     <tr>
#       <th>BBG000BHPKG0</th>
#       <td>32.87%</td>
#     </tr>
#     <tr>
#       <th>BBG000C2NV89</th>
#       <td>32.31%</td>
#     </tr>
#     <tr>
#       <th>BBG000C8FRK0</th>
#       <td>32.10%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>BBG000BFF1J4</th>
#       <td>53.57%</td>
#     </tr>
#     <tr>
#       <th>BBG000BP2H92</th>
#       <td>51.96%</td>
#     </tr>
#     <tr>
#       <th>BBG000BX3B60</th>
#       <td>41.53%</td>
#     </tr>
#     <tr>
#       <th>BBG000BD3J49</th>
#       <td>36.09%</td>
#     </tr>
#     <tr>
#       <th>BBG000CYF8C4</th>
#       <td>35.99%</td>
#     </tr>
#     <tr>
#       <th>BBG000BQ5TK8</th>
#       <td>35.66%</td>
#     </tr>
#     <tr>
#       <th>BBG000CKJ0P3</th>
#       <td>35.40%</td>
#     </tr>
#     <tr>
#       <th>BBG000BHPKG0</th>
#       <td>32.87%</td>
#     </tr>
#     <tr>
#       <th>BBG000C2NV89</th>
#       <td>32.31%</td>
#     </tr>
#     <tr>
#       <th>BBG000C8FRK0</th>
#       <td>32.10%</td>
#     </tr>
#   </tbody>
# </table>
